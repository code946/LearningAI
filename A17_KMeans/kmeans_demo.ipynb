# %% [markdown]
# # 《按图索骥学机器学习》-《A16_KMeans》

# %% [markdown]
# 这是《按图索骥学机器学习》-《A16_KMeans》的讲义
# 这门课程之所以叫按图索骥，是因为学习资料都放到了思维导图当中，大家可以根据自己的情况，选择合适的学习路径，自主学习
#
# ![avatar](pic/swnt.png)
#
# 导图和有关学习资料都放在了github(git.code946.com)上，并且在不断迭代和更新中

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets.samples_generator import make_blobs

# X为样本特征，Y为样本簇类别， 共1000个样本，每个样本2个特征，共4个簇，簇中心在[-1,-1], [0,0],[1,1], [2,2]， 簇方差分别为[0.4, 0.2, 0.2]
X, y = make_blobs(n_samples=1000, n_features=2, centers=[[-1,-1], [0,0], [1,1], [2,2]], cluster_std=[0.4, 0.2, 0.2, 0.2], 
                  random_state =9)
plt.scatter(X[:, 0], X[:, 1], marker='o')
plt.show()

# %%
from sklearn.cluster import KMeans

y_predict = KMeans(n_clusters=2).fit_predict(X)

plt.scatter(X[:,0],X[:,1],c=y_predict)

plt.show()

# %%
from sklearn.metrics import silhouette_score

print(silhouette_score(X,y_predict))
# Out:
# 0.6435178953651656

# %%
y_predict = KMeans(n_clusters=4).fit_predict(X)

plt.scatter(X[:,0],X[:,1],c=y_predict)

plt.show()

# %%
print(silhouette_score(X,y_predict))
# Out:
# 0.6634549555891298

# %%
y_predict = KMeans(n_clusters=5).fit_predict(X)

plt.scatter(X[:,0],X[:,1],c=y_predict)

plt.show()

# %%
print(silhouette_score(X,y_predict))
# Out:
# 0.612514861133172
